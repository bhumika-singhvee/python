# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
data=pd.read_csv('covid_toy.csv')

# %%
data=data.dropna()

# %%
data.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
le=LabelEncoder()
data['gender']=le.fit_transform(data['gender'])
data['cough']=le.fit_transform(data['cough'])
data['city']=le.fit_transform(data['city'])
data['has_covid']=le.fit_transform(data['has_covid'])

# %%
data.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
x=data.drop(columns=['has_covid'])
y=data['has_covid']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
#define neural network architecture
model=tf.keras.Sequential([
    tf.keras.layers.Dense(64,activation='relu',input_dim=x_train.shape[1]),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
loss_fn=tf.keras.losses.BinaryCrossentropy()
metrics=['accuracy']

# %%
learning_rate=0.001
momentum=0.9
optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum)

# %%
model.compile(optimizer=optimizer,loss=loss_fn,metrics=metrics)

# %%
epochs=10
batch_size=32
model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_split=0.2)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 134ms/step - loss: 0.6971 - accuracy: 0.4561 - val_loss: 0.6984 - val_accuracy: 0.6000
# Epoch 2/10
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6968 - accuracy: 0.4561 - val_loss: 0.6977 - val_accuracy: 0.6000
# Epoch 3/10
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6962 - accuracy: 0.4561 - val_loss: 0.6969 - val_accuracy: 0.6000
# Epoch 4/10
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6954 - accuracy: 0.4561 - val_loss: 0.6958 - val_accuracy: 0.6000
# Epoch 5/10
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6946 - accuracy: 0.4561 - val_loss: 0.6946 - val_accuracy: 0.6000
# Epoch 6/10
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6936 - accuracy: 0.4912 - val_loss: 0.6933 - val_accuracy: 0.5333
# Epoch 7/10
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6925 - accuracy: 0.4912 - val_loss: 0.6919 - val_accuracy: 0.5333
# Epoch 8/10
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6913 - accuracy: 0.5088 - val_loss: 0.6905 - val_accuracy: 0.5333
# Epoch 9/10
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6901 - accuracy: 0.5263 - val_loss: 0.6890 - val_accuracy: 0.5333
# Epoch 10/10
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6890 - accuracy: 0.5439 - val_loss: 0.6874 - val_accuracy: 0.5333

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print("Test Loss:",test_loss)
print("Test Accuracy:",test_acc)
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6935 - accuracy: 0.5000
# Test Loss: 0.6935374140739441
# Test Accuracy: 0.5
