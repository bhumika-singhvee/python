# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
a={
    "id":[1,2,3,4,5,6,7,8],
    "Emp_Name":['Raj','Simran','Kiran','Sam','Bhumi','Luv','Khush','Jyoti'],
    "designation":['HR','DA','DD','DS','HR','PD','DP','BA'],
    "Sal":[10000,250000,700000,50000,25000,40000,85000,92000]
}

# %%
a
# Out:
# {'id': [1, 2, 3, 4, 5, 6, 7, 8],
#  'Emp_Name': ['Raj',
#   'Simran',
#   'Kiran',
#   'Sam',
#   'Bhumi',
#   'Luv',
#   'Khush',
#   'Jyoti'],
#  'designation': ['HR', 'DA', 'DD', 'DS', 'HR', 'PD', 'DP', 'BA'],
#  'Sal': [10000, 250000, 700000, 50000, 25000, 40000, 85000, 92000]}

# %%
df=pd.DataFrame(a)

# %%
df
# Out:
#    id Emp_Name designation     Sal
# 0   1      Raj          HR   10000
# 1   2   Simran          DA  250000
# 2   3    Kiran          DD  700000
# 3   4      Sam          DS   50000
# 4   5    Bhumi          HR   25000
# 5   6      Luv          PD   40000
# 6   7    Khush          DP   85000
# 7   8    Jyoti          BA   92000

# %% [markdown]
# 1.head()==>extract top 5 data

# %%
df.head()
# Out:
#    id Emp_Name designation     Sal
# 0   1      Raj          HR   10000
# 1   2   Simran          DA  250000
# 2   3    Kiran          DD  700000
# 3   4      Sam          DS   50000
# 4   5    Bhumi          HR   25000

# %%
df.head(2)
# Out:
#    id Emp_Name designation     Sal
# 0   1      Raj          HR   10000
# 1   2   Simran          DA  250000

# %% [markdown]
# 2.tail()==>extract bottom 5 data

# %%
df.tail()
# Out:
#    id Emp_Name designation    Sal
# 3   4      Sam          DS  50000
# 4   5    Bhumi          HR  25000
# 5   6      Luv          PD  40000
# 6   7    Khush          DP  85000
# 7   8    Jyoti          BA  92000

# %%
df.tail(2)
# Out:
#    id Emp_Name designation    Sal
# 6   7    Khush          DP  85000
# 7   8    Jyoti          BA  92000

# %% [markdown]
# **3 sample()==> randomly indexed data

# %%
df.sample()
# Out:
#    id Emp_Name designation     Sal
# 2   3    Kiran          DD  700000

# %%
df.sample(5)
# Out:
#    id Emp_Name designation     Sal
# 0   1      Raj          HR   10000
# 2   3    Kiran          DD  700000
# 6   7    Khush          DP   85000
# 5   6      Luv          PD   40000
# 7   8    Jyoti          BA   92000

# %%
df.columns
# Out:
# Index(['id', 'Emp_Name', 'designation', 'Sal'], dtype='object')

# %%
#ACOMPLETE OVERVIEW

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           8 non-null      int64
#  1   Emp_Name     8 non-null      object
#  2   designation  8 non-null      object
#  3   Sal          8 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 384.0+ bytes

# %%
df.describe()
# Out:
#             id            Sal
# count  8.00000       8.000000
# mean   4.50000  156500.000000
# std    2.44949  232094.808214
# min    1.00000   10000.000000
# 25%    2.75000   36250.000000
# 50%    4.50000   67500.000000
# 75%    6.25000  131500.000000
# max    8.00000  700000.000000

# %%
df['Sal'][0]=55000
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_528\1034106065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sal'][0]=55000

# %%
df.head()
# Out:
#    id Emp_Name designation     Sal
# 0   1      Raj          HR   55000
# 1   2   Simran          DA  250000
# 2   3    Kiran          DD  700000
# 3   4      Sam          DS   50000
# 4   5    Bhumi          HR   25000

# %%
df['Emp_Name'][0:5]=None
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_528\2670231715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Emp_Name'][0:5]=None

# %%
df['Sal'][0:3]=None
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_528\2407477795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sal'][0:3]=None

# %%
df
# Out:
#    id Emp_Name designation      Sal
# 0   1     None          HR      NaN
# 1   2     None          DA      NaN
# 2   3     None          DD      NaN
# 3   4     None          DS  50000.0
# 4   5     None          HR  25000.0
# 5   6      Luv          PD  40000.0
# 6   7    Khush          DP  85000.0
# 7   8    Jyoti          BA  92000.0

# %%
df.isnull()
# Out:
#       id  Emp_Name  designation    Sal
# 0  False      True        False   True
# 1  False      True        False   True
# 2  False      True        False   True
# 3  False      True        False  False
# 4  False      True        False  False
# 5  False     False        False  False
# 6  False     False        False  False
# 7  False     False        False  False

# %%
df.isnull().sum()
# Out:
# id             0
# Emp_Name       5
# designation    0
# Sal            3
# dtype: int64

# %%
df.dropna()#to remove complete row where data is null
# Out:
#    id Emp_Name designation      Sal
# 5   6      Luv          PD  40000.0
# 6   7    Khush          DP  85000.0
# 7   8    Jyoti          BA  92000.0

# %%
df
# Out:
#    id Emp_Name designation      Sal
# 0   1     None          HR      NaN
# 1   2     None          DA      NaN
# 2   3     None          DD      NaN
# 3   4     None          DS  50000.0
# 4   5     None          HR  25000.0
# 5   6      Luv          PD  40000.0
# 6   7    Khush          DP  85000.0
# 7   8    Jyoti          BA  92000.0

# %%
df['Emp_Name'][0:7]="mohit"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_528\3686794510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Emp_Name'][0:7]="mohit"

# %%
df['Sal'][0:5]=50000

# %%
df
# Out:
#    id Emp_Name designation      Sal
# 0   1    mohit          HR  50000.0
# 1   2    mohit          DA  50000.0
# 2   3    mohit          DD  50000.0
# 3   4    mohit          DS  50000.0
# 4   5    mohit          HR  50000.0
# 5   6    mohit          PD  40000.0
# 6   7    mohit          DP  85000.0
# 7   8    Jyoti          BA  92000.0

# %%
df.loc[3:5,["Emp_Name","Sal"]]
# Out:
#   Emp_Name      Sal
# 3    mohit  50000.0
# 4    mohit  50000.0
# 5    mohit  40000.0

# %%
df.iloc[3:5 ,1:3]#row_range and column_range
# Out:
#   Emp_Name designation
# 3    mohit          DS
# 4    mohit          HR

# %%
df.drop(columns=['Sal'],axis=1)#to drop a column
# Out:
#    id Emp_Name designation
# 0   1    mohit          HR
# 1   2    mohit          DA
# 2   3    mohit          DD
# 3   4    mohit          DS
# 4   5    mohit          HR
# 5   6    mohit          PD
# 6   7    mohit          DP
# 7   8    Jyoti          BA

# %%
df.to_csv("C:\\Users\\User\\Desktop\\New_Emp.csv",index=False)

# %%
df=pd.read_csv("C:\\Users\\User\\Desktop\\placement.csv")

# %%
#how to upload our data

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed  department
# 0  8.14          6.52       1  department
# 1  6.17          5.17       0  department
# 2  8.27          8.86       1  department
# 3  6.88          7.27       1  department
# 4  7.52          7.30       1  department

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed  department
# 95  6.33          6.38       0  department
# 96  8.23          7.76       1  department
# 97  6.65          7.78       0  department
# 98  8.14          5.63       1  department
# 99  6.09          6.61       0  department

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed  department
# 25  7.76          5.68       1  department

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
#  3   department    100 non-null    object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.2+ KB

# %%
#covid
#city wise ==>positive and negative
#top 5 data
#bottom 5 data

# %%
#attrition
#1.reason of attrtion
#2.department
#3.educational field
#4.permotion
#5.working hour
#distance

# %%
p=df.rename(columns={'cgpa':'half_yearly_marks','resume_score':'semester_marks'})

# %%
p
# Out:
#     half_yearly_marks  semester_marks  placed  department
# 0                8.14            6.52       1  department
# 1                6.17            5.17       0  department
# 2                8.27            8.86       1  department
# 3                6.88            7.27       1  department
# 4                7.52            7.30       1  department
# ..                ...             ...     ...         ...
# 95               6.33            6.38       0  department
# 96               8.23            7.76       1  department
# 97               6.65            7.78       0  department
# 98               8.14            5.63       1  department
# 99               6.09            6.61       0  department
#
# [100 rows x 4 columns]

# %%
p=p.iloc[:5 ,3:]
p
# Out:
#    department
# 0  department
# 1  department
# 2  department
# 3  department
# 4  department

# %%
p=df.axes
p
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed', 'department'], dtype='object')]

# %%
p=df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# department       object
# dtype: object

# %%
p=df.empty
p
# Out:
# False

# %%
p=df.ndim
p
# Out:
# 2

# %%
d=df.size
d
# Out:
# 400

# %%
a=df.values
a
# Out:
# array([[8.14, 6.52, 1, 'department'],
#        [6.17, 5.17, 0, 'department'],
#        [8.27, 8.86, 1, 'department'],
#        [6.88, 7.27, 1, 'department'],
#        [7.52, 7.3, 1, 'department'],
#        [8.77, 6.19, 1, 'department'],
#        [5.34, 7.09, 0, 'department'],
#        [6.56, 6.29, 0, 'department'],
#        [6.32, 6.71, 0, 'department'],
#        [7.69, 7.12, 1, 'department'],
#        [6.18, 6.35, 0, 'department'],
#        [5.44, 6.54, 0, 'department'],
#        [6.09, 7.01, 0, 'department'],
#        [8.5, 5.09, 1, 'department'],
#        [7.51, 6.25, 1, 'department'],
#        [8.88, 5.93, 1, 'department'],
#        [8.04, 7.64, 1, 'department'],
#        [7.81, 8.71, 1, 'department'],
#        [5.94, 5.88, 0, 'department'],
#        [6.75, 8.11, 1, 'department'],
#        [5.8, 8.06, 0, 'department'],
#        [6.53, 7.64, 0, 'department'],
#        [6.16, 5.77, 0, 'department'],
#        [6.05, 7.13, 0, 'department'],
#        [8.22, 6.18, 1, 'department'],
# ...

# %%
df=df.copy()
df
# Out:
#     cgpa  resume_score  placed  department
# 0   8.14          6.52       1  department
# 1   6.17          5.17       0  department
# 2   8.27          8.86       1  department
# 3   6.88          7.27       1  department
# 4   7.52          7.30       1  department
# ..   ...           ...     ...         ...
# 95  6.33          6.38       0  department
# 96  8.23          7.76       1  department
# 97  6.65          7.78       0  department
# 98  8.14          5.63       1  department
# 99  6.09          6.61       0  department
#
# [100 rows x 4 columns]

# %%
df=df.sort_values(by="resume_score")
df
# Out:
#     cgpa  resume_score  placed  department
# 94  8.01          4.95       1  department
# 87  5.62          5.05       0  department
# 13  8.50          5.09       1  department
# 41  8.68          5.15       1  department
# 1   6.17          5.17       0  department
# ..   ...           ...     ...         ...
# 17  7.81          8.71       1  department
# 38  6.00          8.72       0  department
# 65  6.04          8.75       0  department
# 2   8.27          8.86       1  department
# 69  8.06          9.06       1  department
#
# [100 rows x 4 columns]

# %%
a=df.sort_index()
a
# Out:
#     cgpa  resume_score  placed  department
# 0   8.14          6.52       1  department
# 1   6.17          5.17       0  department
# 2   8.27          8.86       1  department
# 3   6.88          7.27       1  department
# 4   7.52          7.30       1  department
# ..   ...           ...     ...         ...
# 95  6.33          6.38       0  department
# 96  8.23          7.76       1  department
# 97  6.65          7.78       0  department
# 98  8.14          5.63       1  department
# 99  6.09          6.61       0  department
#
# [100 rows x 4 columns]

# %%
x=df.astype(int)
x
# Out:
#     cgpa  resume_score  placed
# 94     8             4       1
# 87     5             5       0
# 13     8             5       1
# 41     8             5       1
# 1      6             5       0
# ..   ...           ...     ...
# 17     7             8       1
# 38     6             8       0
# 65     6             8       0
# 2      8             8       1
# 69     8             9       1
#
# [100 rows x 3 columns]

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p=df.max()
p
# Out:
# cgpa            9.40
# resume_score    9.06
# placed          1.00
# dtype: float64

# %%
p=df.min()
p
# Out:
# cgpa            5.27
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
a=df.mean()
a
# Out:
# cgpa            6.9422
# resume_score    6.9305
# placed          0.5000
# dtype: float64

# %%
b=df.median()
b
# Out:
# cgpa            6.620
# resume_score    7.055
# placed          0.500
# dtype: float64

# %%
s=df.sum()
s
# Out:
# cgpa            694.22
# resume_score    693.05
# placed           50.00
# dtype: float64

# %%
a=df.filter(items=['cgpa','placed'])
a
# Out:
#     cgpa  placed
# 94  8.01       1
# 87  5.62       0
# 13  8.50       1
# 41  8.68       1
# 1   6.17       0
# ..   ...     ...
# 17  7.81       1
# 38  6.00       0
# 65  6.04       0
# 2   8.27       1
# 69  8.06       1
#
# [100 rows x 2 columns]

# %%
b=df.filter(items=[5,6],axis=0)
b
# Out:
#    cgpa  resume_score  placed
# 5  8.77          6.19       1
# 6  5.34          7.09       0

# %%
t=df.filter(like='5',axis=0)
t
# Out:
#     cgpa  resume_score  placed
# 45  8.10          5.44       1
# 85  6.72          5.46       0
# 25  7.76          5.68       1
# 15  8.88          5.93       1
# 5   8.77          6.19       1
# 95  6.33          6.38       0
# 56  6.13          6.43       0
# 50  8.22          6.74       1
# 55  6.94          6.87       1
# 53  6.00          7.16       0
# 54  5.92          7.18       0
# 57  6.34          7.21       0
# 58  6.47          7.37       0
# 51  6.54          7.39       0
# 35  8.07          7.48       1
# 52  5.90          7.50       0
# 59  5.95          7.57       0
# 75  6.34          7.94       1
# 65  6.04          8.75       0

# %%
s=df.to_dict()
s
# Out:
# {'cgpa': {94: 8.01,
#   87: 5.62,
#   13: 8.5,
#   41: 8.68,
#   1: 6.17,
#   46: 5.83,
#   40: 8.25,
#   45: 8.1,
#   85: 6.72,
#   76: 9.4,
#   90: 5.85,
#   98: 8.14,
#   78: 5.79,
#   25: 7.76,
#   86: 6.18,
#   22: 6.16,
#   18: 5.94,
#   44: 5.47,
#   15: 8.88,
#   82: 7.92,
#   88: 8.07,
#   27: 5.51,
#   24: 8.22,
#   92: 5.43,
#   39: 7.5,
#   5: 8.77,
#   14: 7.51,
#   7: 6.56,
#   91: 8.28,
#   10: 6.18,
#   95: 6.33,
#   56: 6.13,
#   26: 6.27,
#   73: 5.76,
#   84: 5.76,
#   0: 8.14,
#   11: 5.44,
#   48: 5.54,
#   99: 6.09,
#   60: 5.87,
#   8: 6.32,
#   81: 6.12,
#   49: 5.46,
#   50: 8.22,
#   67: 6.59,
#   55: 6.94,
#   42: 6.9,
#   77: 5.88,
#   12: 6.09,
#   31: 5.92,
#   6: 5.34,
#   9: 7.69,
#   23: 6.05,
#   30: 7.36,
#   53: 6.0,
#   54: 5.92,
#   34: 8.87,
#   57: 6.34,
#   3: 6.88,
#   79: 5.27,
#   4: 7.52,
#   29: 6.19,
#   74: 5.54,
#   58: 6.47,
#   51: 6.54,
#   93: 9.31,
#   70: 7.12,
#   35: 8.07,
#   89: 5.99,
#   68: 6.01,
#   52: 5.9,
#   36: 8.16,
# ...

# %%
a=df.abs()
a
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
q=df.to_string()
q
# Out:
# '    cgpa  resume_score  placed\n94  8.01          4.95       1\n87  5.62          5.05       0\n13  8.50          5.09       1\n41  8.68          5.15       1\n1   6.17          5.17       0\n46  5.83          5.21       0\n40  8.25          5.32       1\n45  8.10          5.44       1\n85  6.72          5.46       0\n76  9.40          5.50       1\n90  5.85          5.56       0\n98  8.14          5.63       1\n78  5.79          5.66       0\n25  7.76          5.68       1\n86  6.18          5.76       0\n22  6.16          5.77       0\n18  5.94          5.88       0\n44  5.47          5.92       0\n15  8.88          5.93       1\n82  7.92          6.06       1\n88  8.07          6.07       1\n27  5.51          6.15       0\n24  8.22          6.18       1\n92  5.43          6.18       0\n39  7.50          6.19       1\n5   8.77          6.19       1\n14  7.51          6.25       1\n7   6.56          6.29       0\n91  8.28          6.30       1\n10  6.18          6.35       0\n95  6
# ...

# %%
a=df.columns[2]
a
# Out:
# 'placed'

# %%
s=df.columns.tolist()
s
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
df['half']=df['cgpa'].where(df['cgpa']>50,other=0)
df.head(10)
# Out:
#     cgpa  resume_score  placed  half
# 94  8.01          4.95       1   0.0
# 87  5.62          5.05       0   0.0
# 13  8.50          5.09       1   0.0
# 41  8.68          5.15       1   0.0
# 1   6.17          5.17       0   0.0
# 46  5.83          5.21       0   0.0
# 40  8.25          5.32       1   0.0
# 45  8.10          5.44       1   0.0
# 85  6.72          5.46       0   0.0
# 76  9.40          5.50       1   0.0
