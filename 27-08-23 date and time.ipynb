# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\User\\Desktop\\ML\\click.csv")

# %%
df2=pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df2=pd.read_csv()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %% [markdown]
# extract year

# %%
df2['date']=pd.to_datetime(df2['date'])

# %%
df2['date']
# Out:
# 0        2019-12-16
# 1        2019-12-16
# 2        2019-12-16
# 3        2019-12-16
# 4        2019-12-16
#             ...
# 523679   2019-01-02
# 523680   2019-01-04
# 523681   2019-01-08
# 523682   2019-01-09
# 523683   2019-01-10
# Name: date, Length: 523684, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  10000 non-null  float64
#  1   Age                       10000 non-null  float64
#  2   Area Income               10000 non-null  float64
#  3   Daily Internet Usage      10000 non-null  float64
#  4   Ad Topic Line             10000 non-null  object
#  5   City                      10000 non-null  object
#  6   Gender                    10000 non-null  object
#  7   Country                   10000 non-null  object
#  8   Timestamp                 10000 non-null  object
#  9   Clicked on Ad             10000 non-null  int64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 781.4+ KB

# %% [markdown]
# # extract year

# %%
df2['date_year']=df2['date'].dt.year

# %%
df2['date_year']
# Out:
# 0         2019
# 1         2019
# 2         2019
# 3         2019
# 4         2019
#           ...
# 523679    2019
# 523680    2019
# 523681    2019
# 523682    2019
# 523683    2019
# Name: date_year, Length: 523684, dtype: int64

# %% [markdown]
# # extract month

# %%
df2['date_month']=df2['date'].dt.month

# %%
df2.sample(4)
# Out:
#              date  product_id  city_id  orders  date_year date_month_name  \
# 189130 2019-02-11         539       14       1       2019        February
# 477578 2018-10-22        7239       22       2       2018         October
# 518196 2018-12-11        4659        1       1       2018        December
# 480277 2018-12-22        1208       22       2       2018        December
#
#         date_days
# 189130         11
# 477578         22
# 518196         11
# 480277         22

# %% [markdown]
# # month name

# %%
df2['date_month_name']=df2['date'].dt.month_name()

# %%
df2.sample(4)
# Out:
#              date  product_id  city_id  orders  date_year date_month_name
# 106275 2018-08-25        4847       26       4       2018          August
# 166990 2019-02-02        2154       26       4       2019        February
# 24558  2019-10-12        3734        4      10       2019         October
# 371099 2019-06-15        2196       18       4       2019            June

# %% [markdown]
# # extract days

# %%
df2['date_days']=df2['date'].dt.day

# %%
df2.sample(4)
# Out:
#              date  product_id  city_id  orders  date_year date_month_name  \
# 118353 2018-09-18        1698       14      94       2018       September
# 109423 2018-08-21        1345       13       9       2018          August
# 479095 2018-12-01        3152       22      54       2018        December
# 275684 2019-11-16        3512       16      12       2019        November
#
#         date_days
# 118353         18
# 109423         21
# 479095          1
# 275684         16

# %% [markdown]
# # day of week

# %%
df2['day_dayof week']=df2['date'].dt.dayofweek

# %%
df2.sample(4)
# Out:
#              date  product_id  city_id  orders  date_year date_month_name  \
# 313578 2019-06-13        1536       13      11       2019            June
# 446949 2018-11-13        1622        9       8       2018        November
# 14365  2019-10-17        3851       13       1       2019         October
# 415372 2018-12-04        3541        2       7       2018        December
#
#         date_days  day_dayof week
# 313578         13               3
# 446949         13               1
# 14365          17               3
# 415372          4               1

# %% [markdown]
# # day of week name

# %%
df2['date_day']=df2['date'].dt.day_name()

# %%
df2.sample(4)
# Out:
#              date  product_id  city_id  orders  date_year date_month_name  \
# 445366 2018-12-05        1701        9       1       2018        December
# 118237 2018-07-10         745       14       2       2018            July
# 140410 2018-09-07        5515       22       1       2018       September
# 59271  2019-05-18        6862       24       1       2019             May
#
#         date_days  day_dayof week   date_day
# 445366          5               2  Wednesday
# 118237         10               1    Tuesday
# 140410          7               4     Friday
# 59271          18               5   Saturday

# %% [markdown]
# # is weekend

# %%
df2['day_is_weekend']=np.where(df2['date_day'].isin(['Sunday','Saturday']),1,0)

# %%
df2.sample(8)
# Out:
#              date  product_id  city_id  orders  date_year date_month_name  \
# 246368 2019-03-23        6058        1      58       2019           March
# 325203 2019-06-26        7600       14      14       2019            June
# 406523 2019-01-02        3119       26       1       2019         January
# 4789   2019-12-15        2691       25       5       2019        December
# 251006 2019-01-31        1503       21       4       2019         January
# 474077 2018-10-03        4321       16       1       2018         October
# 294131 2019-08-02        5951       26       1       2019          August
# 124518 2018-07-29        6293       14      53       2018            July
#
#         date_days  day_dayof week   date_day  day_is_weekend
# 246368         23               5   Saturday               1
# 325203         26               2  Wednesday               0
# 406523          2               2  Wednesday               0
# ...

# %% [markdown]
# # extract weak of the year

# %%
df2['date_weak']=df2['date'].dt.week
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1320\2931254455.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df2['date_weak']=df2['date'].dt.week

# %%
df2.sample(8)
# Out:
#              date  product_id  city_id  orders  date_year date_month_name  \
# 146430 2018-09-15        2652       18      20       2018       September
# 241540 2019-02-25        2541       28       3       2019        February
# 443024 2018-11-30        6461       14       1       2018        November
# 501726 2018-12-07        3156        6       2       2018        December
# 250151 2019-02-08        6074       12       1       2019        February
# 139849 2018-08-10        7510       16      12       2018          August
# 58546  2019-05-31        7358       18      19       2019             May
# 251334 2019-03-05        5618       21      18       2019           March
#
#         date_days  day_dayof week  date_day  day_is_weekend  date_weak
# 146430         15               5  Saturday               1         37
# 241540         25               0    Monday               0          9
# 443024         30               4    Friday               0         48
# ...

# %%
df2['quater']=df2['date'].dt.quarter

# %%
df2.head(2)
# Out:
#         date  product_id  city_id  orders  date_year date_month_name  \
# 0 2019-12-16        1897       26       2       2019        December
# 1 2019-12-16        4850       26       4       2019        December
#
#    date_days  day_dayof week date_day  day_is_weekend  date_weak  quater
# 0         16               0   Monday               0         51       4
# 1         16               0   Monday               0         51       4

# %% [markdown]
# # extract time elapsed between dates

# %%
import datetime

# %%
today=datetime.datetime.today()

# %%
today
# Out:
# datetime.datetime(2023, 8, 27, 13, 29, 44, 761371)

# %%
(today-df2['date']).dt.days
# Out:
# 0         1350
# 1         1350
# 2         1350
# 3         1350
# 4         1350
#           ...
# 523679    1698
# 523680    1696
# 523681    1692
# 523682    1691
# 523683    1690
# Name: date, Length: 523684, dtype: int64

# %%
today-df2['date']
# Out:
# 0        1350 days 13:29:44.761371
# 1        1350 days 13:29:44.761371
# 2        1350 days 13:29:44.761371
# 3        1350 days 13:29:44.761371
# 4        1350 days 13:29:44.761371
#                     ...
# 523679   1698 days 13:29:44.761371
# 523680   1696 days 13:29:44.761371
# 523681   1692 days 13:29:44.761371
# 523682   1691 days 13:29:44.761371
# 523683   1690 days 13:29:44.761371
# Name: date, Length: 523684, dtype: timedelta64[ns]

# %%
#coverting to datetime datatype
df['Timestamp']=pd.to_datetime(df['Timestamp'])

# %%
df2.head(2)
# Out:
#         date  product_id  city_id  orders  date_year date_month_name  \
# 0 2019-12-16        1897       26       2       2019        December
# 1 2019-12-16        4850       26       4       2019        December
#
#    date_days  day_dayof week date_day  day_is_weekend  date_weak  quater
# 0         16               0   Monday               0         51       4
# 1         16               0   Monday               0         51       4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  10000 non-null  float64
#  1   Age                       10000 non-null  float64
#  2   Area Income               10000 non-null  float64
#  3   Daily Internet Usage      10000 non-null  float64
#  4   Ad Topic Line             10000 non-null  object
#  5   City                      10000 non-null  object
#  6   Gender                    10000 non-null  object
#  7   Country                   10000 non-null  object
#  8   Timestamp                 10000 non-null  datetime64[ns]
#  9   Clicked on Ad             10000 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 781.4+ KB

# %%
df['hour']=df['Timestamp'].dt.hour
df['minute']=df['Timestamp'].dt.minute
df['second']=df["Timestamp"].dt.second

# %%
df.head(4)
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
#
#                         Country           Timestamp  Clicked on Ad  hour  \
# 0  Svalbard & Jan Mayen Islands 2016-06-09 21:43:05              0    21
# 1                     Singapore 2016-01-16 17:56:05              0    17
# 2                    Guadeloupe 2016-06-29 10:50:45              0    10
# ...

# %%
df['time']=df['Timestamp'].dt.time

# %%
df.sample(3)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 6317                     68.61  40.0     38067.08                153.76
# 3300                     79.52  44.0     57846.68                122.31
# 9385                     40.04  28.0     71222.40                217.37
#
#                         Ad Topic Line       City  Gender    Country  \
# 6317   Inverse zero-defect capability  Youngfort  Female       Peru
# 3300  Profit-focused secondary portal  Sarahland  Female   Bulgaria
# 9385                Inverse local hub  Reyesfurt  Female  Venezuela
#
#                Timestamp  Clicked on Ad  hour  minute  second      time
# 6317 2016-07-13 16:12:24              1    16      12      24  16:12:24
# 3300 2016-04-04 18:36:59              1    18      36      59  18:36:59
# 9385 2016-02-26 01:18:44              0     1      18      44  01:18:44

# %%
df1=pd.read_excel("C:\\Users\\User\\Desktop\\ML\\store.xlsx")

# %%
df1

# %%
df1.info()

# %%
df1['date_year']=df1['Order Date'].dt.year

# %%
df1.sample(4)
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 33653   48684  RW-2015-DP3000109-42069 2015-03-06 2015-03-12  Standard Class
# 9634    22697  IN-2015-JB1592527-42179 2015-06-24 2015-06-30  Standard Class
# 10053   13534  IT-2015-VG2179064-42218 2015-08-02 2015-08-08  Standard Class
# 20244   16289  ES-2012-ME1732045-41076 2012-06-16 2012-06-21  Standard Class
#
#       Customer ID   Customer Name      Segment  Postal Code     City  ...  \
# 33653  DP-3000109   Darren Powers     Consumer          NaN   Butare  ...
# 9634   JB-1592527  Joni Blumstein     Consumer          NaN  Kaiyuan  ...
# 10053  VG-2179064  Vivek Gonzalez     Consumer          NaN     Bari  ...
# 20244  ME-1732045   Maria Etezadi  Home Office          NaN  Talence  ...
#
#               Category Sub-Category                 Product Name    Sales  \
# 33653  Office Supplies          Art         BIC Sketch Pad, Blue   48.660
# ...

# %%
df1['date_month']=df1['Order Date'].dt.month

# %%
df1.sample(4)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 23934   50604    MZ-2015-JW522087-42183 2015-06-28 2015-06-28        Same Day
# 12288   45054   SA-2015-LW7125110-42167 2015-06-12 2015-06-16  Standard Class
# 4101     7142   MX-2012-MB1808582-41262 2012-12-19 2012-12-22    Second Class
# 26055     594  US-2012-JB15400101-40999 2012-03-31 2012-04-04    Second Class
#
#        Customer ID     Customer Name    Segment  Postal Code             City  \
# 23934    JW-522087         Jane Waco  Corporate          NaN           Maputo
# 12288   LW-7125110    Liz Willingham   Consumer          NaN           Riyadh
# 4101    MB-1808582        Mick Brown   Consumer          NaN  San Luis Potosí
# 26055  JB-15400101  Jennifer Braxton  Corporate          NaN             Lima
#
#        ... Sub-Category                             Product Name    Sales  \
# 23934  ...    Envelopes      Kraft Clasp Envelope, Security-Tint   22.800
# ...

# %%
df1['date_month_name']=df1['Order Date'].dt.month_name()

# %%
df1.sample(8)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 49011   38122  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 41581   30537   IN-2013-ME1801092-41282 2013-01-08 2013-01-12    Second Class
# 35865   21198   ID-2015-EM1396059-42253 2015-09-06 2015-09-11    Second Class
# 31735   22245   IN-2014-BN1151527-41661 2014-01-22 2014-01-27  Standard Class
# 23706   36884  CA-2013-GA14725140-41352 2013-03-19 2013-03-20     First Class
# 3125    14626   ES-2015-AG1030045-42297 2015-10-20 2015-10-24    Second Class
# 42649   14812  ES-2014-EG13900120-41803 2014-06-13 2014-06-16    Second Class
# 28776   44339  SA-2015-TS11655110-42084 2015-03-21 2015-03-27  Standard Class
#
#         Customer ID        Customer Name    Segment  Postal Code  \
# 49011  TC-209801402         Tamara Chand  Corporate      47905.0
# 41581    ME-1801092     Michelle Ellison  Corporate          NaN
# 35865    EM-1396059         Eric Murdock   Consumer          NaN
# ...

# %%
df1['date_days']=df1['Order Date'].dt.day

# %%
df1['date_days']
# Out:
# 0        11
# 1         5
# 2        17
# 3        28
# 4         5
#          ..
# 51285    19
# 51286     6
# 51287    26
# 51288    17
# 51289    22
# Name: date_days, Length: 51290, dtype: int64

# %%
df1['date_dayof week']=df1['Order Date'].dt.dayofweek

# %%
df1.sample(4)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 24039   11663   IT-2015-TB2105545-42334 2015-11-26 2015-12-03  Standard Class
# 10648   30660   IN-2013-MY1738092-41583 2013-11-05 2013-11-06        Same Day
# 12621   19340  ES-2012-JD16015120-41077 2012-06-17 2012-06-24  Standard Class
# 15238   13863   ES-2014-MW1823545-41965 2014-11-22 2014-11-26  Standard Class
#
#        Customer ID     Customer Name    Segment  Postal Code             City  \
# 24039   TB-2105545   Ted Butterfield   Consumer          NaN        Vincennes
# 10648   MY-1738092   Maribeth Yedwab  Corporate          NaN        Waitakere
# 12621  JD-16015120       Joy Daniels   Consumer          NaN       Valladolid
# 15238   MW-1823545  Mitch Willingham  Corporate          NaN  Le Blanc-Mesnil
#
#        ... Quantity Discount Profit Shipping Cost Order Priority date_year  \
# 24039  ...        7      0.0  14.70          8.88         Medium      2015
# ...

# %%
import datetime

# %%
today=datetime.datetime.today()

# %%
today
# Out:
# datetime.datetime(2023, 8, 27, 15, 18, 4, 408297)

# %%
(today-df1['Order Date']).dt.days
# Out:
# 0        3211
# 1        3490
# 2        3236
# 3        3498
# 4        3217
#          ...
# 51285    2991
# 51286    3400
# 51287    4018
# 51288    3843
# 51289    3749
# Name: Order Date, Length: 51290, dtype: int64

# %%
df2['date_day']=df2['Order Date'].dt.day_name()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
